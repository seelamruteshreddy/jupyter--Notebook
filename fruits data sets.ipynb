# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree

from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay,confusion_matrix

# %%
fruits=pd.read_csv('c:/data/fruits.csv')
fruits
# Out:
#               color  sphericity  weight   label
# 0            Orange       0.947     120  Orange
# 1            Orange       0.917     125  Orange
# 2            Orange       0.923     110  Orange
# 3            Orange       0.916     123  Orange
# 4            Orange       0.943     124  Orange
# 5            Orange       0.911     130  Orange
# 6            Orange       0.903     135  Orange
# 7            Orange       0.918     105  Orange
# 8            Orange       0.914     132  Orange
# 9            Orange       0.936     127  Orange
# 10  Greenish yellow       0.829     133  Orange
# 11  Greenish yellow       0.875     134  Orange
# 12  Greenish yellow       0.859     110  Orange
# 13            Green       0.849     119  Orange
# 14            Green       0.868     106  Orange
# 15  Greenish yellow       0.884     113  Orange
# 16  Greenish yellow       0.872     108  Orange
# 17  Greenish yellow       0.823     132  Orange
# 18            Green       0.853     119  Orange
# ...

# %%
fruits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   color       60 non-null     object
#  1   sphericity  60 non-null     float64
#  2   weight      60 non-null     int64
#  3   label       60 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.0+ KB

# %%
fruits.isnull().sum()
# Out:
# color         0
# sphericity    0
# weight        0
# label         0
# dtype: int64

# %%
fruits.describe()
# Out:
#        sphericity      weight
# count   60.000000   60.000000
# mean     0.820583  142.750000
# std      0.067577   23.352585
# min      0.710000  101.000000
# 25%      0.767250  124.000000
# 50%      0.823000  143.000000
# 75%      0.870500  164.000000
# max      0.947000  184.000000

# %%
plt.scatter(x='sphericity',y='weight',data=fruits)
plt.show()

# %%
plt.scatter(x='sphericity',y='weight',data=fruits[fruits.label=='Apple'],c='red')
plt.scatter(x='sphericity',y='weight',data=fruits[fruits.label=='Orange'],c='green')
plt.show()

# %%
plt.scatter(x='sphericity',y='weight',data=fruits[fruits.label=='Apple'],c='red')
plt.scatter(x='sphericity',y='weight',data=fruits[fruits.label=='Orange'],c='green')

plt.plot([0.7,0.95],[138,138],c='blue')
plt.plot([0.7,0.95],[147,147],c='blue')
plt.plot([0.796,0.796],[138,147],c='blue')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
X=fruits[['sphericity','weight']]
y=fruits['label']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=10,test_size=0.25)
X_train.shape,X_test.shape
# Out:
# ((45, 2), (15, 2))

# %%
model=DecisionTreeClassifier(criterion='entropy')
model.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
plot_tree(decision_tree=model,feature_names=model.feature_names_in_,class_names=model.classes_,fontsize=8)
plt.show()

# %%
y_predict=model.predict(X_test)
y_predict
# Out:
# array(['Apple', 'Orange', 'Apple', 'Orange', 'Orange', 'Orange', 'Apple',
#        'Orange', 'Orange', 'Orange', 'Apple', 'Apple', 'Orange', 'Apple',
#        'Orange'], dtype=object)

# %%
y_test
# Out:
# 31     Apple
# 3     Orange
# 38     Apple
# 27    Orange
# 21    Orange
# 17    Orange
# 46     Apple
# 2     Orange
# 23    Orange
# 26    Orange
# 35     Apple
# 39     Apple
# 20    Orange
# 37     Apple
# 7     Orange
# Name: label, dtype: object

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay,confusion_matrix

# %%
accuracy_score(y_test,y_predict,normalize=True)
# Out:
# 1.0

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[6, 0],
#        [0, 9]])

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_predict)
plt.show()
